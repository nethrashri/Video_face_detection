# %%
# !pip install opencv-python-headless fer
# Out:
# ...
#   Obtaining dependency information for opencv-python-headless from https://files.pythonhosted.org/packages/1c/9b/583c8d9259f6fc19413f83fd18dd8e6cbc8eefb0b4dc6da52dd151fe3272/opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for fer from https://files.pythonhosted.org/packages/19/d7/cc5954aac8db0be7eaff31c5cd059c23af59391d228c9d09cead0250bdae/fer-22.5.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opencv-contrib-python from https://files.pythonhosted.org/packages/92/64/c1194510eaed272d86b53a08c790ca6ed1c450f06d401c49c8145fc46d40/opencv_contrib_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata
# ...
#   Obtaining dependency information for facenet-pytorch from https://files.pythonhosted.org/packages/ed/2e/2d56386bc2f834cdc683743903852cf1428b4e5ee119f16cf808b589d3cd/facenet_pytorch-2.6.0-py3-none-any.whl.metadata
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
import cv2
import os
from fer import FER
import json

# Load video
video_path = "Bahubali 2 tamil mass scene.mp4"
cap = cv2.VideoCapture(video_path)

# Create directory to save frames
frames_dir = "frames"
if not os.path.exists(frames_dir):
    os.makedirs(frames_dir)

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Save frame as image
    frame_path = os.path.join(frames_dir, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_path, frame)
    frame_count += 1

cap.release()
print(f"Extracted {frame_count} frames.")

# Initialize the emotion detector
detector = FER(mtcnn=True)

# Analyze each frame for emotions
emotion_results = []

for frame_file in sorted(os.listdir(frames_dir)):
    frame_path = os.path.join(frames_dir, frame_file)
    frame = cv2.imread(frame_path)

    # Detect emotions
    emotions = detector.detect_emotions(frame)
    if emotions:
        emotion_results.append({
            "frame": frame_file,
            "emotions": emotions[0]["emotions"]
        })

# Save results
with open("emotion_results.json", "w") as f:
    json.dump(emotion_results, f, indent=4)

print("Emotion detection completed and results saved.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 3
#       1 import cv2
#       2 import os
# ----> 3 from fer import FER
#       4 import json
#       6 # Load video
#
# File ~/anaconda3/lib/python3.11/site-packages/fer/__init__.py:27
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
#      25 import logging
# ---> 27 from .classes import Video
#      28 from .fer import FER
#      30 log = logging.getLogger("fer")
#
# File ~/anaconda3/lib/python3.11/site-packages/fer/classes.py:7
#       5 import os
#       6 import re
# ----> 7 from moviepy.editor import *
#       8 from pathlib import Path
#       9 from typing import Optional, Union
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/editor.py:36
# ...

# %%
import cv2
import os
from fer import FER
import json

# Path to the video file
video_path = "Bahubali 2 tamil mass scene.mp4"

# Load video
cap = cv2.VideoCapture(video_path)

# Create directory to save frames
frames_dir = "frames"
if not os.path.exists(frames_dir):
    os.makedirs(frames_dir)

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Save frame as image
    frame_path = os.path.join(frames_dir, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_path, frame)
    frame_count += 1

cap.release()
print(f"Extracted {frame_count} frames.")

# Initialize the emotion detector
detector = FER(mtcnn=True)

# Analyze each frame for emotions
emotion_results = []

for frame_file in sorted(os.listdir(frames_dir)):
    frame_path = os.path.join(frames_dir, frame_file)
    frame = cv2.imread(frame_path)

    # Detect emotions
    emotions = detector.detect_emotions(frame)
    if emotions:
        emotion_results.append({
            "frame": frame_file,
            "emotions": emotions[0]["emotions"]
        })

# Save results
with open("emotion_results.json", "w") as f:
    json.dump(emotion_results, f, indent=4)

print("Emotion detection completed and results saved.")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 import cv2
#       2 import os
# ----> 3 from fer import FER
#       4 import json
#       6 # Path to the video file
#
# File ~/anaconda3/lib/python3.11/site-packages/fer/__init__.py:27
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
#      25 import logging
# ---> 27 from .classes import Video
#      28 from .fer import FER
#      30 log = logging.getLogger("fer")
#
# File ~/anaconda3/lib/python3.11/site-packages/fer/classes.py:7
#       5 import os
#       6 import re
# ----> 7 from moviepy.editor import *
#       8 from pathlib import Path
#       9 from typing import Optional, Union
#
# ...

# %%
import os
import cv2
from fer import FER
import json

# Set the FFmpeg path if necessary
os.environ["IMAGEIO_FFMPEG_EXE"] = "/usr/local/bin/ffmpeg"

# Path to the video file
video_path = "/Users/yourusername/Documents/Bahubali 2 tamil mass scene.mp4"

# Load video
cap = cv2.VideoCapture(video_path)

# Create directory to save frames
frames_dir = "frames"
if not os.path.exists(frames_dir):
    os.makedirs(frames_dir)

frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Save frame as image
    frame_path = os.path.join(frames_dir, f"frame_{frame_count:04d}.jpg")
    cv2.imwrite(frame_path, frame)
    frame_count += 1

cap.release()
print(f"Extracted {frame_count} frames.")

# Initialize the emotion detector
detector = FER(mtcnn=True)

# Analyze each frame for emotions
emotion_results = []

for frame_file in sorted(os.listdir(frames_dir)):
    frame_path = os.path.join(frames_dir, frame_file)
    frame = cv2.imread(frame_path)

    # Detect emotions
    emotions = detector.detect_emotions(frame)
    if emotions:
        emotion_results.append({
            "frame": frame_file,
            "emotions": emotions[0]["emotions"]
        })

# Save results
with open("emotion_results.json", "w") as f:
    json.dump(emotion_results, f, indent=4)

print("Emotion detection completed and results saved.")

# %%
ffmpeg -version

# %%
Explanation
Setting the Environment Variable: The line os.environ["IMAGEIO_FFMPEG_EXE"] = "/usr/local/bin/ffmpeg" ensures that the path to the FFmpeg executable is correctly set for the imageio library used by MoviePy.
Frame Extraction: The script extracts frames from the video and saves them in the frames directory.
Emotion Detection: Each frame is analyzed for emotions, and the results are saved in emotion_results.json.
This should resolve the FFmpeg issue and allow you to run the script on your MacBook M1 Pro. If you encounter any further issues, please provide the error messages so I can assist you further.
